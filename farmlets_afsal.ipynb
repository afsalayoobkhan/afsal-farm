# %% [markdown]
# # loading the data called afsal.csv

# %%
import pandas as pd

# %% [markdown]
# # defining the file path

# %%
file_path = 'D:\\data science exam\\afsal.csv'
data = pd.read_csv(file_path)

# %% [markdown]
# # you can find the data here

# %%
data
# Out:
#           Date   Time Reporter Farmlet  Active  Relaxed  Fearful  Agitated  \
# 0   06/01/2023  15:00       CM       R     9.2      8.4      0.0       0.0
# 1   06/01/2023  15:00       CM       G     8.5     10.6      0.0       0.0
# 2   06/01/2023  15:00       CM       B    10.0      7.5      0.0       0.0
# 3   06/01/2023  15:00        T       R     9.5      9.5      0.6       0.6
# 4   06/01/2023  15:00        T       G     8.5      8.5      0.8       0.8
# 5   06/01/2023  15:00        T       B     9.0      9.0      1.2       1.2
# 6   13/01/2023  12:20       CM       R    10.0      7.7      0.0       1.3
# 7   13/01/2023  12:20       CM       G     8.5      2.3      2.3       4.3
# 8   13/01/2023  12:20       CM       B     9.3      8.8      0.0       1.3
# 9   19/01/2023  14:50       CM       R     9.5      9.7      0.0       0.0
# 10  19/01/2023  14:50       CM       G     5.1      9.9      0.0       0.0
# ...

# %% [markdown]
# # perfroming ANOVA test to analyse the stastical difference

# %%
import scipy.stats as stats

# %%
from scipy.stats import f_oneway, tukey_hsd

# %%
stats.f_oneway (data['Active'].to_list(),
                data['Relaxed'].to_list(),
                data['Fearful'].to_list(),
                data['Agitated'].to_list(),
                data['Calm'].to_list(),
                data['Content'].to_list(),
                data['Indifferent'].to_list(),
                data['Frustrated'].to_list(),
               )
# Out:
# F_onewayResult(statistic=344.3235146480699, pvalue=3.079537718646044e-159)

# %% [markdown]
# # perfroming Tukey's HSD test

# %%
res = tukey_hsd (data['Active'].to_list(),
                data['Relaxed'].to_list(),
                data['Fearful'].to_list(),
                data['Agitated'].to_list(),
                data['Calm'].to_list(),
                data['Content'].to_list(),
                data['Indifferent'].to_list(),
                data['Frustrated'].to_list(),
               
               )

# %% [markdown]
# # Results

# %%
print (res)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.062     1.000    -0.974     0.849
#  (0 - 2)      7.469     0.000     6.558     8.380
#  (0 - 3)      7.223     0.000     6.312     8.134
#  (0 - 4)     -0.962     0.030    -1.874    -0.051
#  (0 - 5)     -0.556     0.579    -1.467     0.355
#  (0 - 6)      5.392     0.000     4.480     6.303
#  (0 - 7)      7.221     0.000     6.310     8.132
#  (1 - 0)      0.062     1.000    -0.849     0.974
#  (1 - 2)      7.531     0.000     6.620     8.442
#  (1 - 3)      7.285     0.000     6.374     8.197
#  (1 - 4)     -0.900     0.056    -1.811     0.011
#  (1 - 5)     -0.494     0.718    -1.405     0.417
#  (1 - 6)      5.454     0.000     4.543     6.365
#  (1 - 7)      7.283     0.000     6.372     8.195
#  (2 - 0)     -7.469     0.000    -8.380    -6.558
#  (2 - 1)     -7.531     0.000    -8.442    -6.620
# ...

# %% [markdown]
# # Need to plot the data in a bar diagram

# %%
import matplotlib.pyplot as plt

# %%
data= (data['Active'].to_list(),
                data['Relaxed'].to_list(),
                data['Fearful'].to_list(),
                data['Agitated'].to_list(),
                data['Calm'].to_list(),
                data['Content'].to_list(),
                data['Indifferent'].to_list(),
                data['Frustrated'].to_list(),
               )

# %%
data
# Out:
#           Date   Time Reporter Farmlet  Active  Relaxed  Fearful  Agitated  \
# 0   06/01/2023  15:00       CM       R     9.2      8.4      0.0       0.0
# 1   06/01/2023  15:00       CM       G     8.5     10.6      0.0       0.0
# 2   06/01/2023  15:00       CM       B    10.0      7.5      0.0       0.0
# 3   06/01/2023  15:00        T       R     9.5      9.5      0.6       0.6
# 4   06/01/2023  15:00        T       G     8.5      8.5      0.8       0.8
# 5   06/01/2023  15:00        T       B     9.0      9.0      1.2       1.2
# 6   13/01/2023  12:20       CM       R    10.0      7.7      0.0       1.3
# 7   13/01/2023  12:20       CM       G     8.5      2.3      2.3       4.3
# 8   13/01/2023  12:20       CM       B     9.3      8.8      0.0       1.3
# 9   19/01/2023  14:50       CM       R     9.5      9.7      0.0       0.0
# 10  19/01/2023  14:50       CM       G     5.1      9.9      0.0       0.0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv('D:\\data science exam\\afsal.csv')

# %% [markdown]
# # Defiing the different emotional states

# %%
emotional_states = ['Active', 'Relaxed', 'Fearful', 'Agitated', 'Calm', 'Content', 'Indifferent', 'Frustrated']

# %%
if isinstance(data, pd.DataFrame):
    # Calculate the mean and standard error for each emotional state
    means = data[emotional_states].mean()
    errors = data[emotional_states].sem()  # Standard Error of the Mean (SEM)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('D:\\data science exam\\afsal.csv')

# %% [markdown]
# # Run the results of Bar diagram

# %%
plt.bar(emotional_states, means, yerr=errors, capsize=5)
plt.xlabel('Emotional States')  
plt.ylabel('Average Score')
plt.title('Average Scores of Emotional States with Error Bars')
plt.xticks(rotation=45)
plt.show()

# %%
plt.show()

# %%
plt.savefig('D:\\data science exam\\bar_diagram.jpg')
